# %% [markdown]
# # Overall Framework

# %% [markdown]
# **Main Modules in PSMNet**
# 1. Spatial Pyramid Pooling (SPP) Module
# 2. Stacked Hourglass

# %% [markdown]
# ![overall_framework.png](data:image/png;base64,...)

# %%
# !git clone https://github.com/Chohoonhee/PSMNet_Colab
# %cd /content/PSMNet_Colab/PSMnet/
import os.path
from os import path

from google.colab import drive

drive.mount('/content/gdrive/')
datapath = '/content/gdrive/MyDrive/PSMNet/data/KITTI_2015/training/'
savemodel = './saved_model'

if path.exists(savemodel) == False:
    os.mkdir(savemodel)
# Out:
# Cloning into 'PSMNet_Colab'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 41 (delta 13), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 1.07 MiB | 24.38 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# /content/PSMNet_Colab/PSMnet
# Mounted at /content/gdrive/

# %% [markdown]
# ## import module and function

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.utils.data
from torch.autograd import Variable
import torch.nn.functional as F
import torch.optim as optim
import torch
import matplotlib.pyplot as plt
import time
from submodule import *
from preprocess import *
from dataloader import listflowfile as lt
from dataloader.KITTILoader import *
from dataloader.KITTIloader2015 import *

# %% [markdown]
# ## Get dataset string
# ### Get strings such as left image, right image, and disparity in the data path.

# %%
all_left_img, all_right_img, all_left_disp, test_left_img, test_right_img, test_left_disp = dataloader(datapath)
print('left image string:', all_left_img[0])
print('right image string: ', all_right_img[0])
print('left disparity string: ', all_left_disp[0])
print('test left image string: ',test_left_img[0])
print('test right image string: ', test_right_img[0])
# Out:
# left image string: /content/gdrive/MyDrive/PSMNet/data/KITTI_2015/training/image_2/000198_10.png
# right image string:  /content/gdrive/MyDrive/PSMNet/data/KITTI_2015/training/image_3/000198_10.png
# left disparity string:  /content/gdrive/MyDrive/PSMNet/data/KITTI_2015/training/disp_occ_0/000198_10.png
# test left image string:  /content/gdrive/MyDrive/PSMNet/data/KITTI_2015/training/image_2/000019_10.png
# test right image string:  /content/gdrive/MyDrive/PSMNet/data/KITTI_2015/training/image_3/000019_10.png

# %% [markdown]
# ## Define dataloader
# ### Define dataloader using image string.

# %%
KITTI_dataset_train = myImageFloder(all_left_img,all_right_img,all_left_disp, True)
TrainImgLoader = torch.utils.data.DataLoader(KITTI_dataset_train,
      batch_size=1, shuffle= True, num_workers= 8, drop_last=False)
print('Train object: ', TrainImgLoader)
KITTI_dataset_test = myImageFloder(test_left_img, test_right_img, test_left_disp, True)
TestImgLoader = torch.utils.data.DataLoader(KITTI_dataset_test, \
                batch_size=8, shuffle= False, num_workers= 4, drop_last=False)
print('Test object: ', TestImgLoader)
# Out:
# Train object:  <torch.utils.data.dataloader.DataLoader object at 0x7e2406015890>
# Test object:  <torch.utils.data.dataloader.DataLoader object at 0x7e24f7682190>
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# ## Check KITTI dataset data
# ### Plot the images using the KITTI dataset information we defined

# %%
left_img, right_img, left_disp = KITTI_dataset_train.__getitem__(0)
plt.figure()
plt.title('left image')
plt.imshow(left_img.detach().cpu().numpy().transpose(1,2,0))
plt.figure()
plt.title('right image')
plt.imshow(right_img.detach().cpu().numpy().transpose(1,2,0))
plt.figure()
plt.title('ground truth left disparity')
plt.imshow(left_disp)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0665298..2.64].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0151556..2.64].

# %% [markdown]
# ## Define feature extractor
# ### Let`s define a function to extract features from the image
# ### Among them, we will implemet the Spatial pyramid pooling module

# %%
def convbn(in_planes, out_planes, kernel_size, stride, pad, dilation):
    return nn.Sequential(nn.Conv2d(in_planes, out_planes, kernel_size=kernel_size, stride=stride, padding=dilation if dilation > 1 else pad, dilation = dilation, bias=False),
                         nn.BatchNorm2d(out_planes))

# %% [markdown]
# ![first_conv.PNG](data:image/png;base64,...)

# %% [markdown]
# ![SPP.png](data:image/png;base64,...)

# %%
def convbn(in_planes, out_planes, kernel_size, stride, pad, dilation):
    return nn.Sequential(nn.Conv2d(in_planes, out_planes, kernel_size=kernel_size, stride=stride, padding=dilation if dilation > 1 else pad, dilation = dilation, bias=False),
                         nn.BatchNorm2d(out_planes))

class feature_extraction(nn.Module):
    def __init__(self):
        super(feature_extraction, self).__init__()
        self.inplanes = 32


        ### conv0_1, conv0_2, conv0_3
        self.firstconv = nn.Sequential(
            convbn(3, 32, 3, 2, 1, 1),
            nn.ReLU(inplace=False),
            convbn(32, 32, 3, 1, 1, 1),
            nn.ReLU(inplace=False),
            convbn(32, 32, 3, 1, 1, 1),
            nn.ReLU(inplace=False)
        )

        ### conv1_x
        self.layer1 = self._make_layer(BasicBlock, 32, 3, stride=1, pad=1, dilation=1)

        ### conv2_x
        self.layer2 =  self._make_layer(BasicBlock, 64, 16, stride=2, pad=1, dilation=1)

        ### conv3_x
        self.layer3 = self._make_layer(BasicBlock, 128, 3, stride=1, pad=2, dilation=2)

        ### conv4_x
        self.layer4 = self._make_layer(BasicBlock, 128, 3, stride=1, pad=4, dilation=4)

        ### SPP module
        self.branch1 = nn.Sequential(
            nn.AvgPool2d(64, stride=64),
            convbn(128, 32, 1, 1, 0, 1),
            nn.ReLU(inplace=False)
        )

        self.branch2 = nn.Sequential(
            nn.AvgPool2d(32, stride=32),
            convbn(128, 32, 1, 1, 0, 1),
            nn.ReLU(inplace=False)
        )

        self.branch3 = nn.Sequential(
            nn.AvgPool2d(16, stride=16),
            convbn(128, 32, 1, 1, 0, 1),
            nn.ReLU(inplace=False)
        )

        self.branch4 = nn.Sequential(
            nn.AvgPool2d(8, stride=8),
            convbn(128, 32, 1, 1, 0, 1),
            nn.ReLU(inplace=False)
        )


        self.lastconv = nn.Sequential(convbn(320, 128, 3, 1, 1, 1),
                                      nn.ReLU(inplace=True),
                                      nn.Conv2d(128, 32, kernel_size=1, padding=0, stride = 1, bias=False))

    def _make_layer(self, block, planes, blocks, stride, pad, dilation):
        downsample = None
        if stride != 1 or self.inplanes != planes * block.expansion:
           downsample = nn.Sequential(
                nn.Conv2d(self.inplanes, planes * block.expansion,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes * block.expansion),)

        layers = []
        layers.append(block(self.inplanes, planes, stride, downsample, pad, dilation))
        self.inplanes = planes * block.expansion
        for i in range(1, blocks):
            layers.append(block(self.inplanes, planes,1,None,pad,dilation))

        return nn.Sequential(*layers)

    def forward(self, x):
        output      = self.firstconv(x)
        output      = self.layer1(output)
        output_raw  = self.layer2(output)
        output      = self.layer3(output_raw)
        output_skip = self.layer4(output)


        output_branch1 = self.branch1(output_skip)
        output_branch1 = F.upsample(output_branch1, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')

        output_branch2 = self.branch2(output_skip)
        output_branch2 = F.upsample(output_branch2, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')

        output_branch3 = self.branch3(output_skip)
        output_branch3 = F.upsample(output_branch3, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')

        output_branch4 = self.branch4(output_skip)
        output_branch4 = F.upsample(output_branch4, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')

        output_feature = torch.cat((output_raw, output_skip, output_branch4, output_branch3, output_branch2, output_branch1), 1)
        output_feature = self.lastconv(output_feature)

        return output_feature

# %% [markdown]
# ## Define hourglass module
# ### Let`s define hourglass module using 3d convolution and batchnormalization3D
# ### Please refer to convbn_3d function

# %%
def convbn_3d(in_planes, out_planes, kernel_size, stride, pad):
    return nn.Sequential(nn.Conv3d(in_planes, out_planes, kernel_size=kernel_size, padding=pad, stride=stride,bias=False),
                         nn.BatchNorm3d(out_planes))

# %% [markdown]
# ![stackhourglass.png](data:image/png;base64,...)

# %%
class hourglass(nn.Module):
    def __init__(self, inplanes=32):
        super(hourglass, self).__init__()

        ### 3DstackX_1
        self.conv1 = nn.Sequential(
            nn.Conv3d(inplanes, inplanes * 2, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm3d(inplanes * 2),
            nn.ReLU(inplace=False)
        )
        self.conv2 =  nn.Sequential(
            nn.Conv3d(inplanes * 2, inplanes * 2, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm3d(inplanes * 2)
        )

        ### 3DstackX_2
        self.conv3 = nn.Sequential(
            nn.ReLU(inplace=False),
            nn.Conv3d(inplanes * 2, inplanes * 2, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm3d(inplanes * 2),
            nn.ReLU(inplace=False)
        )
        self.conv4 = nn.Sequential(
            nn.Conv3d(inplanes * 2, inplanes * 2, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm3d(inplanes * 2)
        )

        ### 3DstackX_3
        self.conv5 = nn.Sequential(
            nn.ReLU(inplace=False),
            nn.ConvTranspose3d(inplanes * 2, inplanes * 2, kernel_size=3, stride=2, padding=1,
                               output_padding=1, bias=False),
            nn.BatchNorm3d(inplanes * 2)
        )

        ### 3DstackX_4
        self.conv6 = nn.Sequential(
            nn.ReLU(inplace=False),
            nn.ConvTranspose3d(inplanes * 2, inplanes, kernel_size=3, stride=2, padding=1,
                               output_padding=1, bias=False),
            nn.BatchNorm3d(inplanes)
        )


    def forward(self, x, presqu, postsqu):

        out  = self.conv1(x) #in:1/4 out:1/8
        pre  = self.conv2(out) #in:1/8 out:1/8
        if postsqu is not None:
           pre = F.relu(pre + postsqu, inplace=True)
        else:
           pre = F.relu(pre, inplace=True)

        out  = self.conv3(pre) #in:1/8 out:1/16
        out  = self.conv4(out) #in:1/16 out:1/16

        if presqu is not None:
           post = F.relu(self.conv5(out)+presqu, inplace=True) #in:1/16 out:1/8
        else:
           post = F.relu(self.conv5(out)+pre, inplace=True)

        out  = self.conv6(post)  #in:1/8 out:1/4
        return out, pre, post

# %% [markdown]
# ## PSMnet
# ### Define PSMnet
# #### Step1: Define feature extraction part
# #### Step2: Defien 3D convolution part
# #### Step3: weight initialization
# ### PSMnet forward
# #### Step1: In left, right image, feature extraction is performed
# #### Step2: make cost volume.
# #### Step3: cost volume refinement using 3D CNN.
# #### Step4: perform disparity regression.

# %%
class PSMNet(nn.Module):
    def __init__(self, maxdisp):
        super(PSMNet, self).__init__()
        self.maxdisp = maxdisp
        # step1 - feature extractor
        self.feature_extraction = feature_extraction()
        # step2 - 3D convolution part
        self.dres0 = nn.Sequential(convbn_3d(64, 32, 3, 1, 1),
                                     nn.ReLU(inplace=True),
                                     convbn_3d(32, 32, 3, 1, 1),
                                     nn.ReLU(inplace=True))

        self.dres1 = nn.Sequential(convbn_3d(32, 32, 3, 1, 1),
                                   nn.ReLU(inplace=True),
                                   convbn_3d(32, 32, 3, 1, 1))

        self.dres2 = hourglass(32)
        self.dres3 = hourglass(32)
        self.dres4 = hourglass(32)

        self.classif1 = nn.Sequential(convbn_3d(32, 32, 3, 1, 1),
                                      nn.ReLU(inplace=True),
                                      nn.Conv3d(32, 1, kernel_size=3, padding=1, stride=1,bias=False))

        self.classif2 = nn.Sequential(convbn_3d(32, 32, 3, 1, 1),
                                      nn.ReLU(inplace=True),
                                      nn.Conv3d(32, 1, kernel_size=3, padding=1, stride=1,bias=False))

        self.classif3 = nn.Sequential(convbn_3d(32, 32, 3, 1, 1),
                                      nn.ReLU(inplace=True),
                                      nn.Conv3d(32, 1, kernel_size=3, padding=1, stride=1,bias=False))

        # Step3 - weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.Conv3d):
                n = m.kernel_size[0] * m.kernel_size[1]*m.kernel_size[2] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm3d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.bias.data.zero_()


    def forward(self, left, right):
        # Step 1 - feature extraction
        refimg_fea     = self.feature_extraction(left)
        targetimg_fea  = self.feature_extraction(right)


        # Step 2: make cost volume.
        cost = Variable(torch.FloatTensor(refimg_fea.size()[0], refimg_fea.size()[1]*2, self.maxdisp//4,  refimg_fea.size()[2],  refimg_fea.size()[3]).zero_()).cuda()

        for i in range(self.maxdisp//4):
            if i > 0 :
             cost[:, :refimg_fea.size()[1], i, :,i:]   = refimg_fea[:,:,:,i:]
             cost[:, refimg_fea.size()[1]:, i, :,i:] = targetimg_fea[:,:,:,:-i]
            else:
             cost[:, :refimg_fea.size()[1], i, :,:]   = refimg_fea
             cost[:, refimg_fea.size()[1]:, i, :,:]   = targetimg_fea
        cost = cost.contiguous()
        # Step 3: Perform 3D convolution.
        cost0 = self.dres0(cost)
        cost0 = self.dres1(cost0) + cost0

        out1, pre1, post1 = self.dres2(cost0, None, None)
        out1 = out1+cost0

        out2, pre2, post2 = self.dres3(out1, pre1, post1)
        out2 = out2+cost0

        out3, pre3, post3 = self.dres4(out2, pre1, post2)
        out3 = out3+cost0

        cost1 = self.classif1(out1)
        cost2 = self.classif2(out2) + cost1
        cost3 = self.classif3(out3) + cost2
        if self.training:
          cost1 = F.upsample(cost1, [self.maxdisp,left.size()[2],left.size()[3]], mode='trilinear')
          cost2 = F.upsample(cost2, [self.maxdisp,left.size()[2],left.size()[3]], mode='trilinear')

          cost1 = torch.squeeze(cost1,1)
          pred1 = F.softmax(cost1,dim=1)
          pred1 = disparityregression(self.maxdisp)(pred1)

          cost2 = torch.squeeze(cost2,1)
          pred2 = F.softmax(cost2,dim=1)
          pred2 = disparityregression(self.maxdisp)(pred2)

        cost3 = F.upsample(cost3, [self.maxdisp,left.size()[2],left.size()[3]], mode='trilinear')
        cost3 = torch.squeeze(cost3,1)
        pred3 = F.softmax(cost3,dim=1)
        # Step 4: disparity regression.
        pred3 = disparityregression(self.maxdisp)(pred3)

        if self.training:
            return pred1, pred2, pred3
        else:
            return pred3

# %% [markdown]
# ## main function
# ### Specify various hyperparmeters and dataset paths.
# ### Define model.
# ### Defien optimizer.
# ### print model we can see all details of module.

# %%
if __name__=='__main__':
    max_disp = 192
    epochs = 20
    model = PSMNet(max_disp)
    model = model.cuda()
    optimizer = optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    print(model.feature_extraction)
# Out:
# feature_extraction(
#   (firstconv): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU()
#     (2): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ReLU()
#     (4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): ReLU()
#   )
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): BasicBlock(
#       (conv1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (branch1): Sequential(
#     (0): AvgPool2d(kernel_size=64, stride=64, padding=0)
#     (1): Sequential(
#       (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ReLU()
#   )
#   (branch2): Sequential(
#     (0): AvgPool2d(kernel_size=32, stride=32, padding=0)
#     (1): Sequential(
#       (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ReLU()
#   )
#   (branch3): Sequential(
#     (0): AvgPool2d(kernel_size=16, stride=16, padding=0)
#     (1): Sequential(
#       (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ReLU()
#   )
#   (branch4): Sequential(
#     (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#     (1): Sequential(
#       (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ReLU()
#   )
#   (lastconv): Sequential(
#     (0): Sequential(
#       (0): Conv2d(320, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ReLU(inplace=True)
#     (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ## Training with KITTI dataset
# ### Perform training during 1 epoch.
# ### As the loss function, smoothness L1 loss is used
# ### see training log and the training loss normally decreases.

# %%
    for epoch in range(0, epochs):
        total_train_loss = 0
        print('This is %d-th epoch' %(epoch))
        model.train()
        import pdb
        #------------- Train ------------------------------------------------------------
        for batch_idx, (imgL_crop, imgR_crop, disp_crop_L) in enumerate(TrainImgLoader):
            # pdb.set_trace()
            optimizer.zero_grad()
            imgL_crop, imgR_crop, disp_crop_L = imgL_crop.cuda(), imgR_crop.cuda(), disp_crop_L.cuda()
            mask = (disp_crop_L < max_disp) & (0 < disp_crop_L)
            mask.detach_()
            start_time = time.time()
            output = model(imgL_crop, imgR_crop)
            loss = 0.2 * F.smooth_l1_loss(output[0][mask], disp_crop_L[mask], size_average=True) + 0.3 * F.smooth_l1_loss(output[1][mask], disp_crop_L[mask], size_average=True) + 0.5 * F.smooth_l1_loss(output[2][mask], disp_crop_L[mask], size_average=True)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()
            if batch_idx % 3 == 0:
                print('Iter %d training loss = %.3f , time = %.2f' %(batch_idx, loss, time.time() - start_time))
        print('epoch %d total training loss = %.3f' %(epoch, total_train_loss/len(TrainImgLoader)))
        #SAVE
        savefilename = savemodel+'/checkpoint_'+str(epoch)+'.tar'
        torch.save({
            'epoch': epoch,
            'state_dict': model.state_dict(),
            'train_loss': total_train_loss/len(TrainImgLoader),
         }, savefilename)
        #------------- TEST ------------------------------------------------------------
        total_test_loss = 0
        model.eval()
        for batch_idx, (imgL, imgR, disp_L) in enumerate(TestImgLoader):
            test_loss, disp = test(model, imgL,imgR, disp_L)

            print('Iter %d test loss = %.3f' %(batch_idx, test_loss))
            total_test_loss += test_loss
        print('total test loss = %.3f' %(total_test_loss/len(TestImgLoader)))
# Out:
# This is 0-th epoch
# <ipython-input-7-a24d7ff7b28e>:88: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   output_branch1 = F.upsample(output_branch1, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')
# <ipython-input-7-a24d7ff7b28e>:91: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   output_branch2 = F.upsample(output_branch2, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')
# <ipython-input-7-a24d7ff7b28e>:94: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   output_branch3 = F.upsample(output_branch3, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')
# <ipython-input-7-a24d7ff7b28e>:97: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   output_branch4 = F.upsample(output_branch4, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')
# <ipython-input-11-fb010b3f1002>:85: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   cost1 = F.upsample(cost1, [self.maxdisp,left.size()[2],left.size()[3]], mode='trilinear')
# <ipython-input-11-fb010b3f1002>:86: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   cost2 = F.upsample(cost2, [self.maxdisp,left.size()[2],left.size()[3]], mode='trilinear')
# <ipython-input-11-fb010b3f1002>:96: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   cost3 = F.upsample(cost3, [self.maxdisp,left.size()[2],left.size()[3]], mode='trilinear')
# /usr/local/lib/python3.11/dist-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# Iter 0 training loss = 71.148 , time = 2.96
# Iter 3 training loss = 20.787 , time = 0.72
# Iter 6 training loss = 17.780 , time = 0.74
# Iter 9 training loss = 18.198 , time = 0.76
# Iter 12 training loss = 12.339 , time = 0.72
# Iter 15 training loss = 13.382 , time = 0.75
# Iter 18 training loss = 15.084 , time = 0.75
# Iter 21 training loss = 9.884 , time = 0.73
# Iter 24 training loss = 13.118 , time = 0.76
# Iter 27 training loss = 16.490 , time = 0.76
# Iter 30 training loss = 7.639 , time = 0.74
# Iter 33 training loss = 12.769 , time = 0.72
# Iter 36 training loss = 8.460 , time = 0.73
# Iter 39 training loss = 7.589 , time = 0.74
# Iter 42 training loss = 7.253 , time = 0.82
# Iter 45 training loss = 10.691 , time = 0.74
# Iter 48 training loss = 11.724 , time = 0.74
# Iter 51 training loss = 13.089 , time = 0.73
# Iter 54 training loss = 9.402 , time = 0.74
# Iter 57 training loss = 9.496 , time = 0.74
# Iter 60 training loss = 15.076 , time = 0.76
# Iter 63 training loss = 7.592 , time = 0.74
# Iter 66 training loss = 7.216 , time = 0.74
# Iter 69 training loss = 8.053 , time = 0.76
# Iter 72 training loss = 8.353 , time = 0.74
# Iter 75 training loss = 11.125 , time = 0.74
# Iter 78 training loss = 8.410 , time = 0.80
# Iter 81 training loss = 9.402 , time = 0.74
# Iter 84 training loss = 8.507 , time = 0.77
# Iter 87 training loss = 10.547 , time = 0.75
# Iter 90 training loss = 6.929 , time = 0.76
# Iter 93 training loss = 6.495 , time = 0.78
# Iter 96 training loss = 12.196 , time = 0.80
# Iter 99 training loss = 8.063 , time = 0.75
# Iter 102 training loss = 6.631 , time = 0.75
# Iter 105 training loss = 5.990 , time = 0.77
# Iter 108 training loss = 9.236 , time = 0.76
# Iter 111 training loss = 13.805 , time = 0.82
# Iter 114 training loss = 7.624 , time = 0.81
# Iter 117 training loss = 15.483 , time = 0.78
# Iter 120 training loss = 14.161 , time = 0.79
# Iter 123 training loss = 8.521 , time = 0.78
# Iter 126 training loss = 7.850 , time = 0.75
# Iter 129 training loss = 8.466 , time = 0.80
# Iter 132 training loss = 11.646 , time = 0.79
# Iter 135 training loss = 10.859 , time = 0.79
# Iter 138 training loss = 10.907 , time = 0.81
# Iter 141 training loss = 6.847 , time = 0.78
# Iter 144 training loss = 37.034 , time = 0.78
# Iter 147 training loss = 6.876 , time = 0.82
# Iter 150 training loss = 9.990 , time = 0.78
# Iter 153 training loss = 6.716 , time = 0.78
# Iter 156 training loss = 8.438 , time = 0.78
# Iter 159 training loss = 11.432 , time = 0.78
# epoch 0 total training loss = 11.524
# Iter 0 test loss = 22.726
# Iter 1 test loss = 21.655
# Iter 2 test loss = 22.208
# Iter 3 test loss = 22.095
# Iter 4 test loss = 22.961
# total test loss = 22.329
# This is 1-th epoch
# Iter 0 training loss = 33.639 , time = 1.26
# Iter 3 training loss = 13.095 , time = 0.80
# Iter 6 training loss = 9.547 , time = 0.80
# Iter 9 training loss = 11.397 , time = 0.79
# Iter 12 training loss = 7.057 , time = 0.80
# Iter 15 training loss = 4.736 , time = 0.84
# Iter 18 training loss = 8.629 , time = 0.83
# Iter 21 training loss = 11.867 , time = 0.80
# Iter 24 training loss = 18.813 , time = 0.81
# Iter 27 training loss = 10.175 , time = 0.81
# Iter 30 training loss = 10.567 , time = 0.81
# Iter 33 training loss = 9.762 , time = 0.87
# Iter 36 training loss = 15.753 , time = 0.81
# Iter 39 training loss = 9.772 , time = 0.81
# Iter 42 training loss = 8.025 , time = 0.80
# Iter 45 training loss = 18.673 , time = 0.81
# Iter 48 training loss = 4.607 , time = 0.85
# Iter 51 training loss = 9.932 , time = 0.80
# Iter 54 training loss = 8.732 , time = 0.79
# Iter 57 training loss = 9.654 , time = 0.79
# Iter 60 training loss = 9.594 , time = 0.79
# Iter 63 training loss = 10.742 , time = 0.79
# Iter 66 training loss = 9.569 , time = 0.85
# Iter 69 training loss = 7.935 , time = 0.79
# Iter 72 training loss = 5.682 , time = 0.78
# Iter 75 training loss = 9.855 , time = 0.78
# Iter 78 training loss = 8.841 , time = 0.78
# Iter 81 training loss = 5.250 , time = 0.84
# Iter 84 training loss = 8.617 , time = 0.79
# Iter 87 training loss = 11.302 , time = 0.79
# Iter 90 training loss = 7.575 , time = 0.78
# Iter 93 training loss = 9.978 , time = 0.79
# Iter 96 training loss = 11.701 , time = 0.81
# Iter 99 training loss = 6.649 , time = 0.84
# Iter 102 training loss = 7.559 , time = 0.79
# Iter 105 training loss = 6.790 , time = 0.80
# Iter 108 training loss = 5.295 , time = 0.78
# Iter 111 training loss = 8.981 , time = 0.79
# Iter 114 training loss = 10.548 , time = 0.86
# Iter 117 training loss = 13.307 , time = 0.79
# Iter 120 training loss = 8.075 , time = 0.79
# Iter 123 training loss = 7.514 , time = 0.79
# Iter 126 training loss = 6.716 , time = 0.79
# Iter 129 training loss = 9.798 , time = 0.84
# Iter 132 training loss = 7.278 , time = 0.85
# Iter 135 training loss = 9.878 , time = 0.80
# Iter 138 training loss = 5.347 , time = 0.80
# Iter 141 training loss = 9.043 , time = 0.79
# Iter 144 training loss = 11.461 , time = 0.78
# Iter 147 training loss = 5.139 , time = 0.81
# Iter 150 training loss = 13.249 , time = 0.78
# Iter 153 training loss = 20.204 , time = 0.78
# Iter 156 training loss = 11.452 , time = 0.78
# Iter 159 training loss = 6.903 , time = 0.78
# epoch 1 total training loss = 9.930
# Iter 0 test loss = 21.756
# Iter 1 test loss = 21.502
# Iter 2 test loss = 23.100
# Iter 3 test loss = 22.822
# Iter 4 test loss = 22.789
# total test loss = 22.394
# This is 2-th epoch
# Iter 0 training loss = 7.350 , time = 0.94
# Iter 3 training loss = 9.236 , time = 0.79
# Iter 6 training loss = 7.665 , time = 0.85
# Iter 9 training loss = 7.873 , time = 0.80
# Iter 12 training loss = 11.218 , time = 0.79
# Iter 15 training loss = 9.484 , time = 0.79
# Iter 18 training loss = 7.340 , time = 0.79
# Iter 21 training loss = 8.065 , time = 0.84
# Iter 24 training loss = 9.077 , time = 0.85
# Iter 27 training loss = 6.876 , time = 0.79
# Iter 30 training loss = 22.143 , time = 0.80
# Iter 33 training loss = 10.689 , time = 0.79
# Iter 36 training loss = 6.335 , time = 0.80
# Iter 39 training loss = 6.485 , time = 0.85
# Iter 42 training loss = 7.439 , time = 0.79
# Iter 45 training loss = 8.266 , time = 0.79
# Iter 48 training loss = 10.328 , time = 0.80
# Iter 51 training loss = 9.507 , time = 0.79
# Iter 54 training loss = 12.063 , time = 0.85
# Iter 57 training loss = 10.137 , time = 0.86
# Iter 60 training loss = 7.639 , time = 0.80
# Iter 63 training loss = 8.091 , time = 0.80
# Iter 66 training loss = 8.645 , time = 0.79
# Iter 69 training loss = 7.516 , time = 0.80
# Iter 72 training loss = 6.114 , time = 0.86
# Iter 75 training loss = 5.203 , time = 0.79
# Iter 78 training loss = 11.303 , time = 0.79
# Iter 81 training loss = 11.523 , time = 0.80
# Iter 84 training loss = 4.414 , time = 0.79
# Iter 87 training loss = 9.575 , time = 0.86
# Iter 90 training loss = 33.237 , time = 0.85
# Iter 93 training loss = 7.332 , time = 0.80
# Iter 96 training loss = 5.824 , time = 0.79
# Iter 99 training loss = 9.584 , time = 0.80
# Iter 102 training loss = 4.593 , time = 0.80
# Iter 105 training loss = 5.117 , time = 0.85
# Iter 108 training loss = 35.105 , time = 0.79
# Iter 111 training loss = 5.404 , time = 0.79
# Iter 114 training loss = 10.639 , time = 0.80
# Iter 117 training loss = 13.236 , time = 0.79
# Iter 120 training loss = 7.181 , time = 0.85
# Iter 123 training loss = 12.464 , time = 0.83
# Iter 126 training loss = 11.092 , time = 0.81
# Iter 129 training loss = 5.306 , time = 0.79
# Iter 132 training loss = 4.677 , time = 0.80
# Iter 135 training loss = 2.739 , time = 0.79
# Iter 138 training loss = 3.976 , time = 0.85
# Iter 141 training loss = 2.200 , time = 0.80
# Iter 144 training loss = 3.220 , time = 0.78
# Iter 147 training loss = 4.987 , time = 0.78
# Iter 150 training loss = 2.730 , time = 0.78
# Iter 153 training loss = 2.252 , time = 0.81
# Iter 156 training loss = 2.870 , time = 0.83
# Iter 159 training loss = 2.453 , time = 0.78
# epoch 2 total training loss = 8.930
# Iter 0 test loss = 13.472
# Iter 1 test loss = 15.253
# Iter 2 test loss = 13.943
# Iter 3 test loss = 15.460
# Iter 4 test loss = 13.820
# total test loss = 14.389
# This is 3-th epoch
# Iter 0 training loss = 4.218 , time = 1.05
# Iter 3 training loss = 2.373 , time = 0.80
# Iter 6 training loss = 3.057 , time = 0.79
# Iter 9 training loss = 2.429 , time = 0.80
# Iter 12 training loss = 2.396 , time = 0.83
# Iter 15 training loss = 3.590 , time = 0.86
# Iter 18 training loss = 3.022 , time = 0.80
# Iter 21 training loss = 6.172 , time = 0.80
# Iter 24 training loss = 2.138 , time = 0.81
# Iter 27 training loss = 2.810 , time = 0.80
# Iter 30 training loss = 3.268 , time = 0.84
# Iter 33 training loss = 5.172 , time = 0.81
# Iter 36 training loss = 3.489 , time = 0.80
# Iter 39 training loss = 3.781 , time = 0.80
# Iter 42 training loss = 2.666 , time = 0.79
# Iter 45 training loss = 3.985 , time = 0.84
# Iter 48 training loss = 2.681 , time = 0.85
# Iter 51 training loss = 1.861 , time = 0.80
# Iter 54 training loss = 3.139 , time = 0.79
# Iter 57 training loss = 2.066 , time = 0.80
# Iter 60 training loss = 1.723 , time = 0.79
# Iter 63 training loss = 4.005 , time = 0.87
# Iter 66 training loss = 1.953 , time = 0.80
# Iter 69 training loss = 2.126 , time = 0.80
# Iter 72 training loss = 2.917 , time = 0.80
# Iter 75 training loss = 1.799 , time = 0.79
# Iter 78 training loss = 1.457 , time = 0.85
# Iter 81 training loss = 1.888 , time = 0.80
# Iter 84 training loss = 2.313 , time = 0.79
# Iter 87 training loss = 1.522 , time = 0.79
# Iter 90 training loss = 3.267 , time = 0.80
# Iter 93 training loss = 1.615 , time = 0.79
# Iter 96 training loss = 4.928 , time = 0.86
# Iter 99 training loss = 2.126 , time = 0.80
# Iter 102 training loss = 3.743 , time = 0.79
# Iter 105 training loss = 2.804 , time = 0.79
# Iter 108 training loss = 1.673 , time = 0.79
# Iter 111 training loss = 2.423 , time = 0.82
# Iter 114 training loss = 1.454 , time = 0.79
# Iter 117 training loss = 9.167 , time = 0.79
# Iter 120 training loss = 2.500 , time = 0.79
# Iter 123 training loss = 3.599 , time = 0.79
# Iter 126 training loss = 2.666 , time = 0.80
# Iter 129 training loss = 1.439 , time = 0.88
# Iter 132 training loss = 2.628 , time = 0.80
# Iter 135 training loss = 1.624 , time = 0.79
# Iter 138 training loss = 2.372 , time = 0.81
# Iter 141 training loss = 1.210 , time = 0.83
# Iter 144 training loss = 2.194 , time = 0.80
# Iter 147 training loss = 1.327 , time = 0.79
# Iter 150 training loss = 1.051 , time = 0.78
# Iter 153 training loss = 1.796 , time = 0.78
# Iter 156 training loss = 3.360 , time = 0.78
# Iter 159 training loss = 1.856 , time = 0.82
# epoch 3 total training loss = 2.916
# Iter 0 test loss = 13.203
# Iter 1 test loss = 12.837
# Iter 2 test loss = 17.102
# Iter 3 test loss = 10.886
# Iter 4 test loss = 14.156
# total test loss = 13.637
# This is 4-th epoch
# Iter 0 training loss = 1.435 , time = 1.04
# Iter 3 training loss = 1.429 , time = 0.85
# Iter 6 training loss = 1.235 , time = 0.80
# Iter 9 training loss = 2.485 , time = 0.80
# Iter 12 training loss = 1.178 , time = 0.79
# Iter 15 training loss = 4.637 , time = 0.79
# Iter 18 training loss = 5.635 , time = 0.85
# Iter 21 training loss = 1.019 , time = 0.88
# Iter 24 training loss = 0.861 , time = 0.80
# Iter 27 training loss = 1.056 , time = 0.80
# Iter 30 training loss = 0.775 , time = 0.80
# Iter 33 training loss = 1.090 , time = 0.80
# Iter 36 training loss = 3.266 , time = 0.85
# Iter 39 training loss = 1.113 , time = 0.80
# Iter 42 training loss = 1.362 , time = 0.80
# Iter 45 training loss = 1.207 , time = 0.80
# Iter 48 training loss = 0.896 , time = 0.79
# Iter 51 training loss = 1.131 , time = 0.84
# Iter 54 training loss = 1.698 , time = 0.85
# Iter 57 training loss = 1.446 , time = 0.79
# Iter 60 training loss = 1.584 , time = 0.79
# Iter 63 training loss = 0.958 , time = 0.79
# Iter 66 training loss = 1.319 , time = 0.79
# Iter 69 training loss = 1.324 , time = 0.85
# Iter 72 training loss = 0.926 , time = 0.80
# Iter 75 training loss = 2.910 , time = 0.79
# Iter 78 training loss = 3.120 , time = 0.79
# Iter 81 training loss = 0.947 , time = 0.79
# Iter 84 training loss = 1.348 , time = 0.86
# Iter 87 training loss = 1.744 , time = 0.80
# Iter 90 training loss = 0.823 , time = 0.79
# Iter 93 training loss = 2.237 , time = 0.79
# Iter 96 training loss = 1.692 , time = 0.79
# Iter 99 training loss = 1.259 , time = 0.79
# Iter 102 training loss = 1.366 , time = 0.85
# Iter 105 training loss = 3.155 , time = 0.79
# Iter 108 training loss = 1.624 , time = 0.80
# Iter 111 training loss = 1.405 , time = 0.80
# Iter 114 training loss = 1.273 , time = 0.80
# Iter 117 training loss = 3.023 , time = 0.85
# Iter 120 training loss = 2.981 , time = 0.79
# Iter 123 training loss = 0.836 , time = 0.80
# Iter 126 training loss = 1.576 , time = 0.81
# Iter 129 training loss = 0.738 , time = 0.80
# Iter 132 training loss = 8.230 , time = 0.84
# Iter 135 training loss = 2.912 , time = 0.85
# Iter 138 training loss = 1.825 , time = 0.79
# Iter 141 training loss = 1.844 , time = 0.80
# Iter 144 training loss = 2.155 , time = 0.78
# Iter 147 training loss = 1.427 , time = 0.79
# Iter 150 training loss = 1.122 , time = 0.80
# Iter 153 training loss = 1.085 , time = 0.78
# Iter 156 training loss = 2.699 , time = 0.78
# Iter 159 training loss = 0.948 , time = 0.77
# epoch 4 total training loss = 1.891
# Iter 0 test loss = 13.118
# Iter 1 test loss = 12.806
# Iter 2 test loss = 16.321
# Iter 3 test loss = 13.901
# Iter 4 test loss = 14.627
# total test loss = 14.154
# This is 5-th epoch
# Iter 0 training loss = 2.344 , time = 1.12
# Iter 3 training loss = 2.808 , time = 0.79
# Iter 6 training loss = 2.051 , time = 0.79
# Iter 9 training loss = 2.059 , time = 0.85
# Iter 12 training loss = 0.914 , time = 0.79
# Iter 15 training loss = 1.280 , time = 0.81
# Iter 18 training loss = 0.944 , time = 0.86
# Iter 21 training loss = 0.877 , time = 0.80
# Iter 24 training loss = 1.019 , time = 0.80
# Iter 27 training loss = 1.168 , time = 0.87
# Iter 30 training loss = 2.076 , time = 0.79
# Iter 33 training loss = 2.837 , time = 0.80
# Iter 36 training loss = 1.110 , time = 0.80
# Iter 39 training loss = 2.193 , time = 0.80
# Iter 42 training loss = 0.929 , time = 0.85
# Iter 45 training loss = 1.806 , time = 0.80
# Iter 48 training loss = 3.372 , time = 0.79
# Iter 51 training loss = 1.262 , time = 0.80
# Iter 54 training loss = 0.879 , time = 0.79
# Iter 57 training loss = 1.587 , time = 0.81
# Iter 60 training loss = 0.882 , time = 0.86
# Iter 63 training loss = 1.078 , time = 0.80
# Iter 66 training loss = 0.704 , time = 0.80
# Iter 69 training loss = 1.349 , time = 0.79
# Iter 72 training loss = 1.195 , time = 0.79
# Iter 75 training loss = 0.926 , time = 0.86
# Iter 78 training loss = 1.762 , time = 0.79
# Iter 81 training loss = 1.167 , time = 0.79
# Iter 84 training loss = 9.377 , time = 0.79
# Iter 87 training loss = 1.562 , time = 0.94
# Iter 90 training loss = 1.472 , time = 0.82
# Iter 93 training loss = 0.786 , time = 0.84
# Iter 96 training loss = 3.064 , time = 0.79
# Iter 99 training loss = 1.042 , time = 0.79
# Iter 102 training loss = 0.874 , time = 0.79
# Iter 105 training loss = 0.853 , time = 0.80
# Iter 108 training loss = 1.519 , time = 0.83
# Iter 111 training loss = 0.833 , time = 0.79
# Iter 114 training loss = 1.796 , time = 0.80
# Iter 117 training loss = 1.073 , time = 0.79
# Iter 120 training loss = 3.195 , time = 0.79
# Iter 123 training loss = 5.027 , time = 0.83
# Iter 126 training loss = 0.945 , time = 0.85
# Iter 129 training loss = 5.533 , time = 0.79
# Iter 132 training loss = 1.381 , time = 0.79
# Iter 135 training loss = 0.778 , time = 0.79
# Iter 138 training loss = 1.303 , time = 0.80
# Iter 141 training loss = 1.568 , time = 0.85
# Iter 144 training loss = 0.837 , time = 0.78
# Iter 147 training loss = 1.314 , time = 0.78
# Iter 150 training loss = 4.074 , time = 0.78
# Iter 153 training loss = 1.263 , time = 0.78
# Iter 156 training loss = 4.958 , time = 0.81
# Iter 159 training loss = 1.071 , time = 0.82
# epoch 5 total training loss = 1.638
# Iter 0 test loss = 15.649
# Iter 1 test loss = 20.325
# Iter 2 test loss = 18.217
# Iter 3 test loss = 18.758
# Iter 4 test loss = 30.142
# total test loss = 20.618
# This is 6-th epoch
# Iter 0 training loss = 0.873 , time = 1.31
# Iter 3 training loss = 0.776 , time = 0.79
# Iter 6 training loss = 1.277 , time = 0.80
# Iter 9 training loss = 0.590 , time = 0.80
# Iter 12 training loss = 0.591 , time = 0.80
# Iter 15 training loss = 1.371 , time = 0.82
# Iter 18 training loss = 0.933 , time = 0.84
# Iter 21 training loss = 0.578 , time = 0.80
# Iter 24 training loss = 1.380 , time = 0.80
# Iter 27 training loss = 1.312 , time = 0.80
# Iter 30 training loss = 2.770 , time = 0.80
# Iter 33 training loss = 1.318 , time = 0.86
# Iter 36 training loss = 0.805 , time = 0.80
# Iter 39 training loss = 1.563 , time = 0.80
# Iter 42 training loss = 2.151 , time = 0.80
# Iter 45 training loss = 0.881 , time = 0.79
# Iter 48 training loss = 1.073 , time = 0.85
# Iter 51 training loss = 0.900 , time = 0.86
# Iter 54 training loss = 1.325 , time = 0.80
# Iter 57 training loss = 1.631 , time = 0.81
# Iter 60 training loss = 0.777 , time = 0.79
# Iter 63 training loss = 0.978 , time = 0.79
# Iter 66 training loss = 1.499 , time = 0.85
# Iter 69 training loss = 1.131 , time = 0.79
# Iter 72 training loss = 0.754 , time = 0.79
# Iter 75 training loss = 0.748 , time = 0.80
# Iter 78 training loss = 1.581 , time = 0.80
# Iter 81 training loss = 3.546 , time = 0.89
# Iter 84 training loss = 0.552 , time = 0.80
# Iter 87 training loss = 0.675 , time = 0.79
# Iter 90 training loss = 0.861 , time = 0.81
# Iter 93 training loss = 1.785 , time = 0.79
# Iter 96 training loss = 0.597 , time = 0.80
# Iter 99 training loss = 0.919 , time = 0.84
# Iter 102 training loss = 3.357 , time = 0.79
# Iter 105 training loss = 1.014 , time = 0.79
# Iter 108 training loss = 0.808 , time = 0.79
# Iter 111 training loss = 0.806 , time = 0.80
# Iter 114 training loss = 1.325 , time = 0.86
# Iter 117 training loss = 1.612 , time = 0.81
# Iter 120 training loss = 2.321 , time = 0.80
# Iter 123 training loss = 1.299 , time = 0.80
# Iter 126 training loss = 1.352 , time = 0.80
# Iter 129 training loss = 3.285 , time = 0.81
# Iter 132 training loss = 1.340 , time = 0.87
# Iter 135 training loss = 0.875 , time = 0.79
# Iter 138 training loss = 1.224 , time = 0.81
# Iter 141 training loss = 1.310 , time = 0.80
# Iter 144 training loss = 1.759 , time = 0.78
# Iter 147 training loss = 4.702 , time = 0.82
# Iter 150 training loss = 0.736 , time = 0.78
# Iter 153 training loss = 1.127 , time = 0.78
# Iter 156 training loss = 0.948 , time = 0.79
# Iter 159 training loss = 1.437 , time = 0.78
# epoch 6 total training loss = 1.513
# Iter 0 test loss = 11.669
# Iter 1 test loss = 12.599
# Iter 2 test loss = 18.158
# Iter 3 test loss = 13.377
# Iter 4 test loss = 14.318
# total test loss = 14.024
# This is 7-th epoch
# Iter 0 training loss = 1.946 , time = 0.97
# Iter 3 training loss = 1.149 , time = 0.79
# Iter 6 training loss = 1.308 , time = 0.85
# Iter 9 training loss = 0.936 , time = 0.85
# Iter 12 training loss = 0.762 , time = 0.79
# Iter 15 training loss = 1.617 , time = 0.80
# Iter 18 training loss = 1.198 , time = 0.80
# Iter 21 training loss = 0.751 , time = 0.79
# Iter 24 training loss = 0.980 , time = 0.85
# Iter 27 training loss = 1.834 , time = 0.80
# Iter 30 training loss = 1.810 , time = 0.79
# Iter 33 training loss = 0.617 , time = 0.80
# Iter 36 training loss = 1.409 , time = 0.80
# Iter 39 training loss = 0.733 , time = 0.85
# Iter 42 training loss = 1.096 , time = 0.80
# Iter 45 training loss = 1.128 , time = 0.83
# Iter 48 training loss = 1.760 , time = 0.79
# Iter 51 training loss = 1.031 , time = 0.79
# Iter 54 training loss = 0.967 , time = 0.80
# Iter 57 training loss = 0.839 , time = 0.87
# Iter 60 training loss = 1.363 , time = 0.80
# Iter 63 training loss = 0.975 , time = 0.80
# Iter 66 training loss = 0.670 , time = 0.79
# Iter 69 training loss = 2.328 , time = 0.80
# Iter 72 training loss = 1.202 , time = 0.85
# Iter 75 training loss = 0.871 , time = 0.80
# Iter 78 training loss = 1.630 , time = 0.79
# Iter 81 training loss = 0.685 , time = 0.80
# Iter 84 training loss = 2.008 , time = 0.80
# Iter 87 training loss = 0.609 , time = 0.87
# Iter 90 training loss = 0.676 , time = 0.83
# Iter 93 training loss = 0.617 , time = 0.80
# Iter 96 training loss = 1.541 , time = 0.79
# Iter 99 training loss = 1.636 , time = 0.80
# Iter 102 training loss = 1.901 , time = 0.80
# Iter 105 training loss = 0.946 , time = 0.86
# Iter 108 training loss = 8.953 , time = 0.81
# Iter 111 training loss = 1.073 , time = 0.79
# Iter 114 training loss = 0.957 , time = 0.80
# Iter 117 training loss = 0.926 , time = 0.79
# Iter 120 training loss = 1.016 , time = 0.85
# Iter 123 training loss = 1.876 , time = 0.87
# Iter 126 training loss = 0.858 , time = 0.79
# Iter 129 training loss = 1.047 , time = 0.79
# Iter 132 training loss = 2.820 , time = 0.80
# Iter 135 training loss = 0.977 , time = 0.80
# Iter 138 training loss = 0.850 , time = 0.85
# Iter 141 training loss = 5.151 , time = 0.80
# Iter 144 training loss = 2.248 , time = 0.78
# Iter 147 training loss = 6.136 , time = 0.78
# Iter 150 training loss = 1.033 , time = 0.78
# Iter 153 training loss = 0.855 , time = 0.81
# Iter 156 training loss = 0.787 , time = 0.78
# Iter 159 training loss = 1.776 , time = 0.78
# epoch 7 total training loss = 1.564
# Iter 0 test loss = 14.698
# Iter 1 test loss = 16.531
# Iter 2 test loss = 20.029
# Iter 3 test loss = 12.842
# Iter 4 test loss = 17.560
# total test loss = 16.332
# This is 8-th epoch
# Iter 0 training loss = 0.667 , time = 0.99
# Iter 3 training loss = 1.034 , time = 0.79
# Iter 6 training loss = 1.078 , time = 0.79
# Iter 9 training loss = 0.944 , time = 0.80
# Iter 12 training loss = 1.593 , time = 0.86
# Iter 15 training loss = 0.767 , time = 0.86
# Iter 18 training loss = 1.887 , time = 0.80
# Iter 21 training loss = 0.840 , time = 0.83
# Iter 24 training loss = 1.307 , time = 0.80
# Iter 27 training loss = 0.558 , time = 0.80
# Iter 30 training loss = 0.560 , time = 0.87
# Iter 33 training loss = 0.754 , time = 0.79
# Iter 36 training loss = 0.699 , time = 0.79
# Iter 39 training loss = 3.880 , time = 0.79
# Iter 42 training loss = 0.575 , time = 0.80
# Iter 45 training loss = 1.530 , time = 0.84
# Iter 48 training loss = 1.483 , time = 0.80
# Iter 51 training loss = 0.636 , time = 0.80
# Iter 54 training loss = 0.810 , time = 0.81
# Iter 57 training loss = 0.988 , time = 0.80
# Iter 60 training loss = 0.854 , time = 0.80
# Iter 63 training loss = 6.421 , time = 0.85
# Iter 66 training loss = 0.757 , time = 0.80
# Iter 69 training loss = 0.906 , time = 0.80
# Iter 72 training loss = 1.531 , time = 0.80
# Iter 75 training loss = 0.723 , time = 0.80
# Iter 78 training loss = 0.970 , time = 0.88
# Iter 81 training loss = 0.713 , time = 0.80
# Iter 84 training loss = 1.769 , time = 0.79
# Iter 87 training loss = 1.106 , time = 0.79
# Iter 90 training loss = 1.585 , time = 0.80
# Iter 93 training loss = 0.692 , time = 0.84
# Iter 96 training loss = 0.920 , time = 0.85
# Iter 99 training loss = 1.544 , time = 0.80
# Iter 102 training loss = 0.624 , time = 0.80
# Iter 105 training loss = 1.686 , time = 0.79
# Iter 108 training loss = 0.697 , time = 0.79
# Iter 111 training loss = 0.837 , time = 0.86
# Iter 114 training loss = 0.490 , time = 0.79
# Iter 117 training loss = 0.894 , time = 0.80
# Iter 120 training loss = 1.542 , time = 0.79
# Iter 123 training loss = 0.687 , time = 0.79
# Iter 126 training loss = 1.524 , time = 0.85
# Iter 129 training loss = 0.496 , time = 0.83
# Iter 132 training loss = 1.035 , time = 0.80
# Iter 135 training loss = 0.794 , time = 0.80
# Iter 138 training loss = 0.762 , time = 0.80
# Iter 141 training loss = 0.894 , time = 0.80
# Iter 144 training loss = 0.551 , time = 0.81
# Iter 147 training loss = 0.671 , time = 0.79
# Iter 150 training loss = 1.565 , time = 0.78
# Iter 153 training loss = 0.912 , time = 0.78
# Iter 156 training loss = 2.060 , time = 0.78
# Iter 159 training loss = 0.744 , time = 0.82
# epoch 8 total training loss = 1.299
# Iter 0 test loss = 16.380
# Iter 1 test loss = 12.811
# Iter 2 test loss = 14.848
# Iter 3 test loss = 12.300
# Iter 4 test loss = 14.659
# total test loss = 14.200
# This is 9-th epoch
# Iter 0 training loss = 0.940 , time = 1.02
# Iter 3 training loss = 1.203 , time = 0.86
# Iter 6 training loss = 2.040 , time = 0.79
# Iter 9 training loss = 0.743 , time = 0.79
# Iter 12 training loss = 2.261 , time = 0.79
# Iter 15 training loss = 0.596 , time = 0.79
# Iter 18 training loss = 1.374 , time = 0.86
# Iter 21 training loss = 1.538 , time = 0.86
# Iter 24 training loss = 1.030 , time = 0.81
# Iter 27 training loss = 0.828 , time = 0.79
# Iter 30 training loss = 0.889 , time = 0.79
# Iter 33 training loss = 0.498 , time = 0.82
# Iter 36 training loss = 1.799 , time = 0.84
# Iter 39 training loss = 3.272 , time = 0.79
# Iter 42 training loss = 0.906 , time = 0.79
# Iter 45 training loss = 1.475 , time = 0.80
# Iter 48 training loss = 1.294 , time = 0.79
# Iter 51 training loss = 0.925 , time = 0.83
# Iter 54 training loss = 1.367 , time = 0.84
# Iter 57 training loss = 3.914 , time = 0.83
# Iter 60 training loss = 0.701 , time = 0.81
# Iter 63 training loss = 3.155 , time = 0.80
# Iter 66 training loss = 0.507 , time = 0.79
# Iter 69 training loss = 0.609 , time = 0.86
# Iter 72 training loss = 2.150 , time = 0.81
# Iter 75 training loss = 0.689 , time = 0.80
# Iter 78 training loss = 0.794 , time = 0.79
# Iter 81 training loss = 0.969 , time = 0.81
# Iter 84 training loss = 0.469 , time = 0.86
# Iter 87 training loss = 0.954 , time = 0.80
# Iter 90 training loss = 0.973 , time = 0.80
# Iter 93 training loss = 1.506 , time = 0.80
# Iter 96 training loss = 0.682 , time = 0.80
# Iter 99 training loss = 0.828 , time = 0.80
# Iter 102 training loss = 0.880 , time = 0.86
# Iter 105 training loss = 0.722 , time = 0.79
# Iter 108 training loss = 2.122 , time = 0.80
# Iter 111 training loss = 0.725 , time = 0.80
# Iter 114 training loss = 0.686 , time = 0.79
# Iter 117 training loss = 2.138 , time = 0.85
# Iter 120 training loss = 0.577 , time = 0.80
# Iter 123 training loss = 0.409 , time = 0.79
# Iter 126 training loss = 0.675 , time = 0.81
# Iter 129 training loss = 1.060 , time = 0.81
# Iter 132 training loss = 1.331 , time = 0.83
# Iter 135 training loss = 1.978 , time = 0.82
# Iter 138 training loss = 1.100 , time = 0.79
# Iter 141 training loss = 0.789 , time = 0.79
# Iter 144 training loss = 0.773 , time = 0.79
# Iter 147 training loss = 0.437 , time = 0.79
# Iter 150 training loss = 1.153 , time = 0.80
# Iter 153 training loss = 0.769 , time = 0.78
# Iter 156 training loss = 1.663 , time = 0.78
# Iter 159 training loss = 1.599 , time = 0.77
# epoch 9 total training loss = 1.203
# Iter 0 test loss = 13.671
# Iter 1 test loss = 12.982
# Iter 2 test loss = 15.377
# Iter 3 test loss = 17.901
# Iter 4 test loss = 16.084
# total test loss = 15.203
# This is 10-th epoch
# Iter 0 training loss = 1.263 , time = 0.94
# Iter 3 training loss = 0.930 , time = 0.80
# Iter 6 training loss = 1.060 , time = 0.79
# Iter 9 training loss = 1.957 , time = 0.87
# Iter 12 training loss = 0.509 , time = 0.82
# Iter 15 training loss = 0.500 , time = 0.80
# Iter 18 training loss = 0.771 , time = 0.79
# Iter 21 training loss = 0.777 , time = 0.81
# Iter 24 training loss = 6.935 , time = 0.79
# Iter 27 training loss = 0.291 , time = 0.85
# Iter 30 training loss = 0.909 , time = 0.80
# Iter 33 training loss = 1.003 , time = 0.80
# Iter 36 training loss = 0.708 , time = 0.80
# Iter 39 training loss = 0.705 , time = 0.79
# Iter 42 training loss = 1.015 , time = 0.86
# Iter 45 training loss = 0.556 , time = 0.80
# Iter 48 training loss = 0.666 , time = 0.79
# Iter 51 training loss = 1.195 , time = 0.80
# Iter 54 training loss = 0.796 , time = 0.79
# Iter 57 training loss = 1.518 , time = 0.85
# Iter 60 training loss = 0.522 , time = 0.86
# Iter 63 training loss = 0.827 , time = 0.79
# Iter 66 training loss = 2.659 , time = 0.80
# Iter 69 training loss = 0.820 , time = 0.80
# Iter 72 training loss = 0.431 , time = 0.80
# Iter 75 training loss = 1.590 , time = 0.86
# Iter 78 training loss = 0.690 , time = 0.80
# Iter 81 training loss = 1.084 , time = 0.80
# Iter 84 training loss = 0.459 , time = 0.80
# Iter 87 training loss = 0.783 , time = 0.80
# Iter 90 training loss = 0.593 , time = 0.84
# Iter 93 training loss = 0.340 , time = 0.84
# Iter 96 training loss = 2.457 , time = 0.80
# Iter 99 training loss = 0.890 , time = 0.81
# Iter 102 training loss = 1.133 , time = 0.80
# Iter 105 training loss = 3.087 , time = 0.80
# Iter 108 training loss = 1.192 , time = 0.87
# Iter 111 training loss = 1.007 , time = 0.79
# Iter 114 training loss = 1.712 , time = 0.81
# Iter 117 training loss = 0.621 , time = 0.80
# Iter 120 training loss = 0.719 , time = 0.79
# Iter 123 training loss = 0.934 , time = 0.83
# Iter 126 training loss = 0.387 , time = 0.85
# Iter 129 training loss = 1.422 , time = 0.80
# Iter 132 training loss = 1.051 , time = 0.79
# Iter 135 training loss = 1.290 , time = 0.80
# Iter 138 training loss = 0.507 , time = 0.80
# Iter 141 training loss = 0.609 , time = 0.84
# Iter 144 training loss = 0.602 , time = 0.77
# Iter 147 training loss = 2.679 , time = 0.78
# Iter 150 training loss = 1.200 , time = 0.77
# Iter 153 training loss = 2.369 , time = 0.78
# Iter 156 training loss = 1.133 , time = 0.81
# Iter 159 training loss = 1.513 , time = 0.81
# epoch 10 total training loss = 1.052
# Iter 0 test loss = 13.872
# Iter 1 test loss = 12.878
# Iter 2 test loss = 16.127
# Iter 3 test loss = 14.863
# Iter 4 test loss = 18.517
# total test loss = 15.251
# This is 11-th epoch
# Iter 0 training loss = 0.482 , time = 1.27
# Iter 3 training loss = 0.846 , time = 0.80
# Iter 6 training loss = 0.642 , time = 0.79
# Iter 9 training loss = 1.267 , time = 0.80
# Iter 12 training loss = 1.460 , time = 0.80
# Iter 15 training loss = 1.464 , time = 0.87
# Iter 18 training loss = 3.233 , time = 0.87
# Iter 21 training loss = 1.334 , time = 0.80
# Iter 24 training loss = 0.636 , time = 0.80
# Iter 27 training loss = 1.157 , time = 0.80
# Iter 30 training loss = 1.092 , time = 0.80
# Iter 33 training loss = 0.562 , time = 0.87
# Iter 36 training loss = 0.561 , time = 0.80
# Iter 39 training loss = 1.114 , time = 0.81
# Iter 42 training loss = 0.533 , time = 0.81
# Iter 45 training loss = 0.995 , time = 0.80
# Iter 48 training loss = 1.359 , time = 0.84
# Iter 51 training loss = 0.552 , time = 0.80
# Iter 54 training loss = 0.523 , time = 0.80
# Iter 57 training loss = 0.882 , time = 0.79
# Iter 60 training loss = 0.467 , time = 0.80
# Iter 63 training loss = 1.186 , time = 0.82
# Iter 66 training loss = 0.701 , time = 0.88
# Iter 69 training loss = 1.627 , time = 0.80
# Iter 72 training loss = 0.525 , time = 0.79
# Iter 75 training loss = 0.591 , time = 0.80
# Iter 78 training loss = 1.704 , time = 0.79
# Iter 81 training loss = 0.461 , time = 0.86
# Iter 84 training loss = 1.794 , time = 0.79
# Iter 87 training loss = 2.224 , time = 0.80
# Iter 90 training loss = 1.146 , time = 0.80
# Iter 93 training loss = 0.973 , time = 0.79
# Iter 96 training loss = 0.380 , time = 0.87
# Iter 99 training loss = 0.600 , time = 0.85
# Iter 102 training loss = 0.907 , time = 0.79
# Iter 105 training loss = 1.668 , time = 0.79
# Iter 108 training loss = 0.929 , time = 0.79
# Iter 111 training loss = 0.924 , time = 0.79
# Iter 114 training loss = 0.966 , time = 0.89
# Iter 117 training loss = 1.659 , time = 0.79
# Iter 120 training loss = 1.586 , time = 0.79
# Iter 123 training loss = 0.377 , time = 0.81
# Iter 126 training loss = 1.532 , time = 0.79
# Iter 129 training loss = 0.677 , time = 0.86
# Iter 132 training loss = 0.884 , time = 0.85
# Iter 135 training loss = 1.740 , time = 0.80
# Iter 138 training loss = 2.027 , time = 0.81
# Iter 141 training loss = 3.480 , time = 0.80
# Iter 144 training loss = 0.635 , time = 0.78
# Iter 147 training loss = 0.782 , time = 0.82
# Iter 150 training loss = 0.959 , time = 0.78
# Iter 153 training loss = 1.346 , time = 0.78
# Iter 156 training loss = 2.573 , time = 0.79
# Iter 159 training loss = 0.878 , time = 0.79
# epoch 11 total training loss = 1.114
# Iter 0 test loss = 13.188
# Iter 1 test loss = 16.418
# Iter 2 test loss = 19.210
# Iter 3 test loss = 13.902
# Iter 4 test loss = 16.776
# total test loss = 15.899
# This is 12-th epoch
# Iter 0 training loss = 1.493 , time = 1.06
# Iter 3 training loss = 0.554 , time = 0.80
# Iter 6 training loss = 1.499 , time = 0.86
# Iter 9 training loss = 1.360 , time = 0.79
# Iter 12 training loss = 1.101 , time = 0.80
# Iter 15 training loss = 3.232 , time = 0.81
# Iter 18 training loss = 0.722 , time = 0.79
# Iter 21 training loss = 0.672 , time = 0.86
# Iter 24 training loss = 0.585 , time = 0.79
# Iter 27 training loss = 0.654 , time = 0.80
# Iter 30 training loss = 1.050 , time = 0.80
# Iter 33 training loss = 1.875 , time = 0.80
# Iter 36 training loss = 0.620 , time = 0.79
# Iter 39 training loss = 0.539 , time = 0.86
# Iter 42 training loss = 0.682 , time = 0.80
# Iter 45 training loss = 0.550 , time = 0.79
# Iter 48 training loss = 1.434 , time = 0.79
# Iter 51 training loss = 0.784 , time = 0.80
# Iter 54 training loss = 0.602 , time = 0.85
# Iter 57 training loss = 0.452 , time = 0.80
# Iter 60 training loss = 1.842 , time = 0.79
# Iter 63 training loss = 0.342 , time = 0.80
# Iter 66 training loss = 1.148 , time = 0.79
# Iter 69 training loss = 0.533 , time = 0.83
# Iter 72 training loss = 0.748 , time = 0.87
# Iter 75 training loss = 0.492 , time = 0.79
# Iter 78 training loss = 0.343 , time = 0.79
# Iter 81 training loss = 0.678 , time = 0.80
# Iter 84 training loss = 0.865 , time = 0.79
# Iter 87 training loss = 0.967 , time = 0.83
# Iter 90 training loss = 0.676 , time = 0.79
# Iter 93 training loss = 1.595 , time = 0.79
# Iter 96 training loss = 2.175 , time = 0.79
# Iter 99 training loss = 0.824 , time = 0.79
# Iter 102 training loss = 7.525 , time = 0.85
# Iter 105 training loss = 0.934 , time = 0.86
# Iter 108 training loss = 4.398 , time = 0.79
# Iter 111 training loss = 0.908 , time = 0.80
# Iter 114 training loss = 0.773 , time = 0.79
# Iter 117 training loss = 1.049 , time = 0.79
# Iter 120 training loss = 0.959 , time = 0.85
# Iter 123 training loss = 1.270 , time = 0.79
# Iter 126 training loss = 1.173 , time = 0.82
# Iter 129 training loss = 1.038 , time = 0.80
# Iter 132 training loss = 0.872 , time = 0.79
# Iter 135 training loss = 0.354 , time = 0.86
# Iter 138 training loss = 0.489 , time = 0.79
# Iter 141 training loss = 3.082 , time = 0.80
# Iter 144 training loss = 0.450 , time = 0.78
# Iter 147 training loss = 1.508 , time = 0.78
# Iter 150 training loss = 3.764 , time = 0.79
# Iter 153 training loss = 1.389 , time = 0.80
# Iter 156 training loss = 0.745 , time = 0.78
# Iter 159 training loss = 0.789 , time = 0.79
# epoch 12 total training loss = 1.208
# Iter 0 test loss = 12.541
# Iter 1 test loss = 17.791
# Iter 2 test loss = 19.237
# Iter 3 test loss = 22.905
# Iter 4 test loss = 17.802
# total test loss = 18.055
# This is 13-th epoch
# Iter 0 training loss = 0.476 , time = 0.99
# Iter 3 training loss = 0.535 , time = 0.80
# Iter 6 training loss = 0.696 , time = 0.80
# Iter 9 training loss = 1.858 , time = 0.80
# Iter 12 training loss = 0.752 , time = 0.86
# Iter 15 training loss = 0.597 , time = 0.81
# Iter 18 training loss = 0.388 , time = 0.80
# Iter 21 training loss = 0.690 , time = 0.79
# Iter 24 training loss = 0.547 , time = 0.80
# Iter 27 training loss = 5.083 , time = 0.82
# Iter 30 training loss = 2.956 , time = 0.85
# Iter 33 training loss = 0.442 , time = 0.80
# Iter 36 training loss = 0.821 , time = 0.79
# Iter 39 training loss = 0.665 , time = 0.79
# Iter 42 training loss = 0.581 , time = 0.80
# Iter 45 training loss = 2.981 , time = 0.86
# Iter 48 training loss = 1.234 , time = 0.79
# Iter 51 training loss = 1.044 , time = 0.79
# Iter 54 training loss = 0.861 , time = 0.80
# Iter 57 training loss = 0.572 , time = 0.80
# Iter 60 training loss = 0.811 , time = 0.85
# Iter 63 training loss = 0.896 , time = 0.84
# Iter 66 training loss = 0.681 , time = 0.81
# Iter 69 training loss = 0.757 , time = 0.79
# Iter 72 training loss = 1.649 , time = 0.80
# Iter 75 training loss = 1.584 , time = 0.80
# Iter 78 training loss = 1.201 , time = 0.86
# Iter 81 training loss = 0.613 , time = 0.79
# Iter 84 training loss = 0.610 , time = 0.79
# Iter 87 training loss = 0.881 , time = 0.80
# Iter 90 training loss = 1.056 , time = 0.79
# Iter 93 training loss = 0.586 , time = 0.86
# Iter 96 training loss = 1.212 , time = 0.79
# Iter 99 training loss = 2.987 , time = 0.80
# Iter 102 training loss = 0.317 , time = 0.79
# Iter 105 training loss = 1.561 , time = 0.79
# Iter 108 training loss = 1.102 , time = 0.81
# Iter 111 training loss = 0.875 , time = 0.85
# Iter 114 training loss = 0.652 , time = 0.79
# Iter 117 training loss = 2.218 , time = 0.79
# Iter 120 training loss = 0.420 , time = 0.80
# Iter 123 training loss = 0.327 , time = 0.80
# Iter 126 training loss = 0.376 , time = 0.86
# Iter 129 training loss = 0.470 , time = 0.80
# Iter 132 training loss = 0.785 , time = 0.80
# Iter 135 training loss = 0.503 , time = 0.80
# Iter 138 training loss = 1.213 , time = 0.79
# Iter 141 training loss = 0.922 , time = 0.83
# Iter 144 training loss = 0.538 , time = 0.84
# Iter 147 training loss = 0.476 , time = 0.78
# Iter 150 training loss = 0.838 , time = 0.79
# Iter 153 training loss = 0.708 , time = 0.79
# Iter 156 training loss = 0.476 , time = 0.78
# Iter 159 training loss = 0.877 , time = 0.81
# epoch 13 total training loss = 1.125
# Iter 0 test loss = 12.403
# Iter 1 test loss = 14.643
# Iter 2 test loss = 17.396
# Iter 3 test loss = 20.341
# Iter 4 test loss = 18.699
# total test loss = 16.696
# This is 14-th epoch
# Iter 0 training loss = 0.726 , time = 0.99
# Iter 3 training loss = 2.023 , time = 0.86
# Iter 6 training loss = 2.870 , time = 0.80
# Iter 9 training loss = 0.547 , time = 0.80
# Iter 12 training loss = 0.258 , time = 0.79
# Iter 15 training loss = 0.775 , time = 0.79
# Iter 18 training loss = 0.527 , time = 0.84
# Iter 21 training loss = 0.750 , time = 0.80
# Iter 24 training loss = 0.845 , time = 0.80
# Iter 27 training loss = 0.424 , time = 0.80
# Iter 30 training loss = 1.099 , time = 0.79
# Iter 33 training loss = 0.221 , time = 0.80
# Iter 36 training loss = 1.389 , time = 0.85
# Iter 39 training loss = 0.504 , time = 0.80
# Iter 42 training loss = 0.981 , time = 0.81
# Iter 45 training loss = 0.438 , time = 0.80
# Iter 48 training loss = 0.685 , time = 0.80
# Iter 51 training loss = 0.483 , time = 0.85
# Iter 54 training loss = 1.064 , time = 0.79
# Iter 57 training loss = 0.493 , time = 0.80
# Iter 60 training loss = 0.734 , time = 0.80
# Iter 63 training loss = 0.694 , time = 0.79
# Iter 66 training loss = 0.496 , time = 0.84
# Iter 69 training loss = 0.657 , time = 0.87
# Iter 72 training loss = 0.381 , time = 0.80
# Iter 75 training loss = 1.328 , time = 0.80
# Iter 78 training loss = 0.406 , time = 0.79
# Iter 81 training loss = 0.577 , time = 0.80
# Iter 84 training loss = 0.396 , time = 0.85
# Iter 87 training loss = 1.059 , time = 0.80
# Iter 90 training loss = 1.188 , time = 0.81
# Iter 93 training loss = 0.907 , time = 0.79
# Iter 96 training loss = 0.513 , time = 0.80
# Iter 99 training loss = 0.639 , time = 0.86
# Iter 102 training loss = 0.497 , time = 0.85
# Iter 105 training loss = 0.638 , time = 0.79
# Iter 108 training loss = 0.962 , time = 0.80
# Iter 111 training loss = 1.330 , time = 0.79
# Iter 114 training loss = 0.795 , time = 0.81
# Iter 117 training loss = 1.777 , time = 0.85
# Iter 120 training loss = 0.356 , time = 0.80
# Iter 123 training loss = 0.598 , time = 0.80
# Iter 126 training loss = 1.494 , time = 0.80
# Iter 129 training loss = 0.799 , time = 0.80
# Iter 132 training loss = 0.511 , time = 0.85
# Iter 135 training loss = 0.640 , time = 0.80
# Iter 138 training loss = 0.484 , time = 0.79
# Iter 141 training loss = 0.784 , time = 0.79
# Iter 144 training loss = 0.629 , time = 0.78
# Iter 147 training loss = 0.724 , time = 0.78
# Iter 150 training loss = 0.964 , time = 0.82
# Iter 153 training loss = 0.493 , time = 0.78
# Iter 156 training loss = 0.733 , time = 0.79
# Iter 159 training loss = 0.786 , time = 0.78
# epoch 14 total training loss = 0.847
# Iter 0 test loss = 17.306
# Iter 1 test loss = 13.673
# Iter 2 test loss = 19.806
# Iter 3 test loss = 13.726
# Iter 4 test loss = 20.695
# total test loss = 17.041
# This is 15-th epoch
# Iter 0 training loss = 1.089 , time = 1.08
# Iter 3 training loss = 0.489 , time = 0.79
# Iter 6 training loss = 0.399 , time = 0.79
# Iter 9 training loss = 0.514 , time = 0.86
# Iter 12 training loss = 2.849 , time = 0.80
# Iter 15 training loss = 0.509 , time = 0.80
# Iter 18 training loss = 1.664 , time = 0.80
# Iter 21 training loss = 0.430 , time = 0.79
# Iter 24 training loss = 1.421 , time = 0.87
# Iter 27 training loss = 0.714 , time = 0.80
# Iter 30 training loss = 0.548 , time = 0.80
# Iter 33 training loss = 0.308 , time = 0.80
# Iter 36 training loss = 0.694 , time = 0.84
# Iter 39 training loss = 0.538 , time = 0.79
# Iter 42 training loss = 0.311 , time = 0.89
# Iter 45 training loss = 1.759 , time = 0.80
# Iter 48 training loss = 0.496 , time = 0.80
# Iter 51 training loss = 0.834 , time = 0.79
# Iter 54 training loss = 0.530 , time = 0.79
# Iter 57 training loss = 1.491 , time = 0.86
# Iter 60 training loss = 0.609 , time = 0.79
# Iter 63 training loss = 2.882 , time = 0.79
# Iter 66 training loss = 0.673 , time = 0.80
# Iter 69 training loss = 0.734 , time = 0.80
# Iter 72 training loss = 0.682 , time = 0.84
# Iter 75 training loss = 0.912 , time = 0.86
# Iter 78 training loss = 0.441 , time = 0.80
# Iter 81 training loss = 0.565 , time = 0.80
# Iter 84 training loss = 0.316 , time = 0.79
# Iter 87 training loss = 0.391 , time = 0.80
# Iter 90 training loss = 0.384 , time = 0.86
# Iter 93 training loss = 1.265 , time = 0.79
# Iter 96 training loss = 1.360 , time = 0.80
# Iter 99 training loss = 0.597 , time = 0.80
# Iter 102 training loss = 0.724 , time = 0.79
# Iter 105 training loss = 0.812 , time = 0.83
# Iter 108 training loss = 0.428 , time = 0.85
# Iter 111 training loss = 0.449 , time = 0.79
# Iter 114 training loss = 0.566 , time = 0.79
# Iter 117 training loss = 1.623 , time = 0.80
# Iter 120 training loss = 0.334 , time = 0.79
# Iter 123 training loss = 0.485 , time = 0.83
# Iter 126 training loss = 0.921 , time = 0.80
# Iter 129 training loss = 0.801 , time = 0.81
# Iter 132 training loss = 0.219 , time = 0.80
# Iter 135 training loss = 0.475 , time = 0.79
# Iter 138 training loss = 1.728 , time = 0.86
# Iter 141 training loss = 0.516 , time = 0.84
# Iter 144 training loss = 0.267 , time = 0.78
# Iter 147 training loss = 1.260 , time = 0.78
# Iter 150 training loss = 0.961 , time = 0.78
# Iter 153 training loss = 2.981 , time = 0.79
# Iter 156 training loss = 0.562 , time = 0.81
# Iter 159 training loss = 0.945 , time = 0.78
# epoch 15 total training loss = 0.928
# Iter 0 test loss = 14.465
# Iter 1 test loss = 20.689
# Iter 2 test loss = 18.257
# Iter 3 test loss = 13.392
# Iter 4 test loss = 16.845
# total test loss = 16.730
# This is 16-th epoch
# Iter 0 training loss = 0.431 , time = 1.20
# Iter 3 training loss = 0.629 , time = 0.79
# Iter 6 training loss = 0.593 , time = 0.79
# Iter 9 training loss = 0.788 , time = 0.79
# Iter 12 training loss = 1.575 , time = 0.80
# Iter 15 training loss = 1.532 , time = 0.86
# Iter 18 training loss = 0.614 , time = 0.81
# Iter 21 training loss = 1.141 , time = 0.80
# Iter 24 training loss = 0.401 , time = 0.80
# Iter 27 training loss = 1.924 , time = 0.81
# Iter 30 training loss = 0.521 , time = 0.84
# Iter 33 training loss = 3.613 , time = 0.88
# Iter 36 training loss = 0.332 , time = 0.80
# Iter 39 training loss = 1.614 , time = 0.80
# Iter 42 training loss = 0.612 , time = 0.81
# Iter 45 training loss = 2.237 , time = 0.80
# Iter 48 training loss = 0.761 , time = 0.86
# Iter 51 training loss = 1.034 , time = 0.80
# Iter 54 training loss = 0.660 , time = 0.79
# Iter 57 training loss = 0.710 , time = 0.79
# Iter 60 training loss = 0.651 , time = 0.80
# Iter 63 training loss = 0.880 , time = 0.86
# Iter 66 training loss = 4.973 , time = 0.81
# Iter 69 training loss = 0.569 , time = 0.80
# Iter 72 training loss = 2.991 , time = 0.79
# Iter 75 training loss = 0.582 , time = 0.80
# Iter 78 training loss = 0.596 , time = 0.79
# Iter 81 training loss = 0.526 , time = 0.84
# Iter 84 training loss = 0.628 , time = 0.79
# Iter 87 training loss = 0.850 , time = 0.80
# Iter 90 training loss = 0.865 , time = 0.80
# Iter 93 training loss = 0.779 , time = 0.79
# Iter 96 training loss = 1.737 , time = 0.85
# Iter 99 training loss = 1.221 , time = 0.80
# Iter 102 training loss = 0.370 , time = 0.80
# Iter 105 training loss = 0.616 , time = 0.80
# Iter 108 training loss = 0.459 , time = 0.79
# Iter 111 training loss = 0.614 , time = 0.83
# Iter 114 training loss = 0.798 , time = 0.87
# Iter 117 training loss = 1.968 , time = 0.79
# Iter 120 training loss = 0.256 , time = 0.80
# Iter 123 training loss = 1.894 , time = 0.81
# Iter 126 training loss = 0.682 , time = 0.79
# Iter 129 training loss = 0.667 , time = 0.86
# Iter 132 training loss = 0.567 , time = 0.80
# Iter 135 training loss = 0.693 , time = 0.79
# Iter 138 training loss = 1.869 , time = 0.80
# Iter 141 training loss = 0.928 , time = 0.80
# Iter 144 training loss = 0.859 , time = 0.81
# Iter 147 training loss = 0.351 , time = 0.82
# Iter 150 training loss = 0.920 , time = 0.78
# Iter 153 training loss = 0.830 , time = 0.77
# Iter 156 training loss = 1.102 , time = 0.78
# Iter 159 training loss = 0.632 , time = 0.78
# epoch 16 total training loss = 1.047
# Iter 0 test loss = 14.052
# Iter 1 test loss = 12.067
# Iter 2 test loss = 17.175
# Iter 3 test loss = 15.068
# Iter 4 test loss = 12.598
# total test loss = 14.192
# This is 17-th epoch
# Iter 0 training loss = 2.216 , time = 1.10
# Iter 3 training loss = 0.457 , time = 0.80
# Iter 6 training loss = 0.557 , time = 0.86
# Iter 9 training loss = 0.535 , time = 0.79
# Iter 12 training loss = 1.549 , time = 0.80
# Iter 15 training loss = 0.605 , time = 0.79
# Iter 18 training loss = 0.713 , time = 0.79
# Iter 21 training loss = 1.043 , time = 0.86
# Iter 24 training loss = 0.543 , time = 0.84
# Iter 27 training loss = 2.555 , time = 0.80
# Iter 30 training loss = 2.372 , time = 0.80
# Iter 33 training loss = 1.094 , time = 0.79
# Iter 36 training loss = 0.507 , time = 0.85
# Iter 39 training loss = 0.768 , time = 0.86
# Iter 42 training loss = 0.475 , time = 0.80
# Iter 45 training loss = 0.800 , time = 0.81
# Iter 48 training loss = 0.853 , time = 0.80
# Iter 51 training loss = 0.828 , time = 0.80
# Iter 54 training loss = 1.148 , time = 0.83
# Iter 57 training loss = 0.593 , time = 0.80
# Iter 60 training loss = 1.308 , time = 0.80
# Iter 63 training loss = 2.485 , time = 0.80
# Iter 66 training loss = 0.720 , time = 0.79
# Iter 69 training loss = 1.590 , time = 0.85
# Iter 72 training loss = 1.494 , time = 0.86
# Iter 75 training loss = 0.743 , time = 0.80
# Iter 78 training loss = 1.352 , time = 0.80
# Iter 81 training loss = 2.123 , time = 0.79
# Iter 84 training loss = 0.527 , time = 0.80
# Iter 87 training loss = 0.590 , time = 0.84
# Iter 90 training loss = 1.000 , time = 0.79
# Iter 93 training loss = 0.758 , time = 0.80
# Iter 96 training loss = 1.571 , time = 0.80
# Iter 99 training loss = 0.934 , time = 0.80
# Iter 102 training loss = 1.146 , time = 0.86
# Iter 105 training loss = 0.468 , time = 0.85
# Iter 108 training loss = 1.026 , time = 0.79
# Iter 111 training loss = 0.890 , time = 0.80
# Iter 114 training loss = 0.337 , time = 0.79
# Iter 117 training loss = 0.644 , time = 0.79
# Iter 120 training loss = 0.914 , time = 0.88
# Iter 123 training loss = 1.055 , time = 0.79
# Iter 126 training loss = 0.995 , time = 0.80
# Iter 129 training loss = 0.299 , time = 0.79
# Iter 132 training loss = 0.354 , time = 0.79
# Iter 135 training loss = 0.749 , time = 0.87
# Iter 138 training loss = 1.171 , time = 0.79
# Iter 141 training loss = 0.441 , time = 0.79
# Iter 144 training loss = 0.342 , time = 0.79
# Iter 147 training loss = 0.871 , time = 0.78
# Iter 150 training loss = 1.338 , time = 0.78
# Iter 153 training loss = 0.462 , time = 0.82
# Iter 156 training loss = 0.591 , time = 0.78
# Iter 159 training loss = 0.686 , time = 0.78
# epoch 17 total training loss = 1.097
# Iter 0 test loss = 14.778
# Iter 1 test loss = 14.377
# Iter 2 test loss = 17.037
# Iter 3 test loss = 14.379
# Iter 4 test loss = 14.746
# total test loss = 15.063
# This is 18-th epoch
# Iter 0 training loss = 0.671 , time = 1.15
# Iter 3 training loss = 0.775 , time = 0.79
# Iter 6 training loss = 2.388 , time = 0.80
# Iter 9 training loss = 0.583 , time = 0.80
# Iter 12 training loss = 0.485 , time = 0.84
# Iter 15 training loss = 0.796 , time = 0.79
# Iter 18 training loss = 0.667 , time = 0.79
# Iter 21 training loss = 0.543 , time = 0.80
# Iter 24 training loss = 1.259 , time = 0.79
# Iter 27 training loss = 2.435 , time = 0.84
# Iter 30 training loss = 1.029 , time = 0.79
# Iter 33 training loss = 0.454 , time = 0.80
# Iter 36 training loss = 0.651 , time = 0.79
# Iter 39 training loss = 0.768 , time = 0.80
# Iter 42 training loss = 0.806 , time = 0.80
# Iter 45 training loss = 0.557 , time = 0.85
# Iter 48 training loss = 2.238 , time = 0.79
# Iter 51 training loss = 0.285 , time = 0.80
# Iter 54 training loss = 0.375 , time = 0.79
# Iter 57 training loss = 0.369 , time = 0.79
# Iter 60 training loss = 0.614 , time = 0.84
# Iter 63 training loss = 1.261 , time = 0.80
# Iter 66 training loss = 0.294 , time = 0.80
# Iter 69 training loss = 0.907 , time = 0.79
# Iter 72 training loss = 0.732 , time = 0.80
# Iter 75 training loss = 1.097 , time = 0.79
# Iter 78 training loss = 1.010 , time = 0.89
# Iter 81 training loss = 0.990 , time = 0.80
# Iter 84 training loss = 2.159 , time = 0.80
# Iter 87 training loss = 1.218 , time = 0.80
# Iter 90 training loss = 0.709 , time = 0.80
# Iter 93 training loss = 0.600 , time = 0.84
# Iter 96 training loss = 1.112 , time = 0.79
# Iter 99 training loss = 0.438 , time = 0.79
# Iter 102 training loss = 0.331 , time = 0.80
# Iter 105 training loss = 0.241 , time = 0.80
# Iter 108 training loss = 0.527 , time = 0.82
# Iter 111 training loss = 0.713 , time = 0.86
# Iter 114 training loss = 0.745 , time = 0.81
# Iter 117 training loss = 0.365 , time = 0.79
# Iter 120 training loss = 1.579 , time = 0.79
# Iter 123 training loss = 0.295 , time = 0.81
# Iter 126 training loss = 0.441 , time = 0.84
# Iter 129 training loss = 1.670 , time = 0.80
# Iter 132 training loss = 0.655 , time = 0.80
# Iter 135 training loss = 0.543 , time = 0.79
# Iter 138 training loss = 0.667 , time = 0.80
# Iter 141 training loss = 0.425 , time = 0.85
# Iter 144 training loss = 0.435 , time = 0.82
# Iter 147 training loss = 0.405 , time = 0.78
# Iter 150 training loss = 1.029 , time = 0.78
# Iter 153 training loss = 0.652 , time = 0.78
# Iter 156 training loss = 1.129 , time = 0.79
# Iter 159 training loss = 0.533 , time = 0.81
# epoch 18 total training loss = 0.892
# Iter 0 test loss = 12.247
# Iter 1 test loss = 16.060
# Iter 2 test loss = 18.079
# Iter 3 test loss = 15.937
# Iter 4 test loss = 15.973
# total test loss = 15.659
# This is 19-th epoch
# Iter 0 training loss = 0.516 , time = 1.04
# Iter 3 training loss = 1.730 , time = 0.83
# Iter 6 training loss = 0.809 , time = 0.80
# Iter 9 training loss = 1.554 , time = 0.80
# Iter 12 training loss = 0.958 , time = 0.80
# Iter 15 training loss = 1.233 , time = 0.80
# Iter 18 training loss = 0.636 , time = 0.84
# Iter 21 training loss = 2.721 , time = 0.80
# Iter 24 training loss = 1.173 , time = 0.80
# Iter 27 training loss = 3.599 , time = 0.80
# Iter 30 training loss = 1.112 , time = 0.79
# Iter 33 training loss = 1.463 , time = 0.83
# Iter 36 training loss = 1.150 , time = 0.86
# Iter 39 training loss = 1.015 , time = 0.80
# Iter 42 training loss = 1.547 , time = 0.80
# Iter 45 training loss = 3.482 , time = 0.79
# Iter 48 training loss = 1.199 , time = 0.80
# Iter 51 training loss = 4.853 , time = 0.84
# Iter 54 training loss = 2.021 , time = 0.80
# Iter 57 training loss = 0.758 , time = 0.80
# Iter 60 training loss = 1.204 , time = 0.79
# Iter 63 training loss = 0.685 , time = 0.79
# Iter 66 training loss = 0.929 , time = 0.83
# Iter 69 training loss = 0.536 , time = 0.83
# Iter 72 training loss = 1.464 , time = 0.80
# Iter 75 training loss = 0.986 , time = 0.79
# Iter 78 training loss = 0.654 , time = 0.79
# Iter 81 training loss = 0.432 , time = 0.79
# Iter 84 training loss = 0.482 , time = 0.85
# Iter 87 training loss = 1.878 , time = 0.81
# Iter 90 training loss = 0.440 , time = 0.79
# Iter 93 training loss = 0.628 , time = 0.79
# Iter 96 training loss = 0.661 , time = 0.80
# Iter 99 training loss = 2.028 , time = 0.82
# Iter 102 training loss = 0.357 , time = 0.86
# Iter 105 training loss = 0.559 , time = 0.80
# Iter 108 training loss = 0.614 , time = 0.79
# Iter 111 training loss = 1.072 , time = 0.80
# Iter 114 training loss = 0.729 , time = 0.80
# Iter 117 training loss = 1.095 , time = 0.84
# Iter 120 training loss = 1.184 , time = 0.79
# Iter 123 training loss = 2.078 , time = 0.80
# Iter 126 training loss = 0.629 , time = 0.79
# Iter 129 training loss = 0.534 , time = 0.79
# Iter 132 training loss = 0.982 , time = 0.83
# Iter 135 training loss = 0.545 , time = 0.86
# Iter 138 training loss = 0.852 , time = 0.79
# Iter 141 training loss = 0.630 , time = 0.79
# Iter 144 training loss = 1.939 , time = 0.78
# Iter 147 training loss = 0.699 , time = 0.78
# Iter 150 training loss = 0.408 , time = 0.81
# Iter 153 training loss = 1.395 , time = 0.78
# Iter 156 training loss = 0.682 , time = 0.79
# Iter 159 training loss = 1.252 , time = 0.79
# epoch 19 total training loss = 1.333
# Iter 0 test loss = 12.804
# Iter 1 test loss = 16.070
# Iter 2 test loss = 20.081
# Iter 3 test loss = 18.712
# Iter 4 test loss = 16.556
# total test loss = 16.845

# %% [markdown]
# ## Test with KITTI test sample
# ### Let`s print the disparity image using data from the test set.
# ### Because training takes a long time, we use a pretrained model.

# %%
left_image_path = '/content/gdrive/My Drive/PSMNet/data/KITTI_2015/testing/left.png'
right_image_path = '/content/gdrive/My Drive/PSMNet/data/KITTI_2015/testing/right.png'

# %%
  def test_img(imgL,imgR):
      model.eval()

      imgL = imgL.cuda()
      imgR = imgR.cuda()

      with torch.no_grad():
          disp = model(imgL,imgR)

      disp = torch.squeeze(disp)
      pred_disp = disp.data.cpu().numpy()

      return pred_disp
if __name__=='__main__':
    from collections import OrderedDict
    # checkpoint = torch.load('/content/gdrive/My Drive/PSMNet/data/pretrained_model_KITTI2015.tar')
    checkpoint = torch.load('./saved_model/checkpoint_3.tar')
    new_state_dict = OrderedDict()
    for k, v in checkpoint['state_dict'].items():
        # name = k[7:]
        name = k
        new_state_dict[name] = v
    model.load_state_dict(new_state_dict)
    normal_mean_var = {'mean': [0.485, 0.456, 0.406],
                        'std': [0.229, 0.224, 0.225]}
    infer_transform = transforms.Compose([transforms.ToTensor(),
                                          transforms.Normalize(**normal_mean_var)])

    imgL_o = Image.open(left_image_path).convert('RGB')
    imgR_o = Image.open(right_image_path).convert('RGB')

    imgL = infer_transform(imgL_o)
    imgR = infer_transform(imgR_o)

    # pad to width and hight to 16 times
    if imgL.shape[1] % 16 != 0:
        times = imgL.shape[1]//16
        top_pad = (times+1)*16 -imgL.shape[1]
    else:
        top_pad = 0

    if imgL.shape[2] % 16 != 0:
        times = imgL.shape[2]//16
        right_pad = (times+1)*16-imgL.shape[2]
    else:
        right_pad = 0

    imgL = F.pad(imgL,(0,right_pad, top_pad,0)).unsqueeze(0)
    imgR = F.pad(imgR,(0,right_pad, top_pad,0)).unsqueeze(0)

    start_time = time.time()
    pred_disp = test_img(imgL,imgR)
    if top_pad !=0 or right_pad != 0:
      img = pred_disp[top_pad:,:-right_pad]
    else:
      img = pred_disp
    plt.figure()
    plt.title('left image')
    plt.imshow(imgL_o)
    plt.figure()
    plt.title('disparity output')
    plt.imshow(img)
    plt.show()
    print('time = %.2f' %(time.time() - start_time))
# Out:
# <ipython-input-7-a24d7ff7b28e>:88: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   output_branch1 = F.upsample(output_branch1, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')
# <ipython-input-7-a24d7ff7b28e>:91: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   output_branch2 = F.upsample(output_branch2, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')
# <ipython-input-7-a24d7ff7b28e>:94: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   output_branch3 = F.upsample(output_branch3, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')
# <ipython-input-7-a24d7ff7b28e>:97: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   output_branch4 = F.upsample(output_branch4, (output_skip.size()[2],output_skip.size()[3]),mode='bilinear')
# <ipython-input-11-fb010b3f1002>:96: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   cost3 = F.upsample(cost3, [self.maxdisp,left.size()[2],left.size()[3]], mode='trilinear')
# time = 1.21
